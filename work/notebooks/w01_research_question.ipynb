# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jfran03/flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I will be choosing: Growth / Recovery / Momentum Prediction
#
# Formal research question: Can a page's future traffic behaviour be predicted from its past state?
#
# On a personal note: being able to predict future behaviours is not an easy to do, I want to challenge myself and make my time worth it by doing this freestyle project as my path. I believe the things I learn to perform this path would prepare me for my future engamgements with ML topics (Quant!!!).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

#

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
#
# What decision does it improve: Which pages to put in front of a review this week, ranked by risk of continued decline or evidence of building momentum. It helps decide whether a page is worth reviewing or not.
#
# Who acts on it: A SEO/content reviewer with a given weekly capacity
#
# What is the cost of a wrong forecast: Two given scenarios, one of them is WAY worse than the other
#
# 1. False positive: A reviewer wastes their time reviewing a page that wasn't actually at risk
#
# 2. False negative: A page experencing a declining trend compounds without anything flagging it, and caught when its too late. If a false negative is caught when traffic declines, that's lost business.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# let's do some EDA on the sample data

import pandas as pd

res = pd.read_csv("../../outputs/refresh_queue_sample.csv")

n_pages = len(res)
n_declining = int(res['is_declining_label'].sum())
decline_rate = n_declining / n_pages * 100

print(f"{n_pages} pages in the sample")
print(f"{n_declining} flagged declining ({decline_rate:.1f}%)")
print()

# trend_direction -> is_declining_label: this queue file doesn't carry the raw
# trend_pct (that only lives in the starter dataset), but the same rule holds —
# trend_direction is never a feature for predicting is_declining_label.
print(res[['trend_direction', 'is_declining_label']].head(10).to_string(index=False))
# Out:
# 200 pages in the sample
# 197 flagged declining (98.5%)
#
# trend_direction  is_declining_label
#            down                   1
#            down                   1
#            down                   1
#            down                   1
#            down                   1
#            down                   1
#            down                   1
#            down                   1
#            down                   1
#            down                   1

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# stable
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# up
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# down
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
